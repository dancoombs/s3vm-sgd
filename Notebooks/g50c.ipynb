# %%
from scipy import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from svm_custom import SVM

# %%
data = io.loadmat("g50c.mat")
data.keys()
X = data['X'].astype(np.double)
y = data['y'].astype(np.double)
y = y.reshape(y.shape[0])

# perm = np.random.permutation(len(X))
# X = X[perm]
# y = y[perm]

X, y = shuffle(X, y, random_state=0)

# %%
mysvm = SVM(C=10, kernel='rbf', gamma=0.5)
mysvm.fit(X, y)
mysvm.score(X, y)
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  1.6806e+03 -9.1972e+03  1e+04  2e-14  3e-15
#  1:  1.3512e+00 -1.1577e+03  1e+03  2e-14  1e-15
#  2: -2.6487e+02 -4.0219e+02  1e+02  1e-14  5e-16
#  3: -2.7499e+02 -2.7905e+02  4e+00  8e-15  3e-16
#  4: -2.7500e+02 -2.7504e+02  4e-02  2e-14  2e-16
#  5: -2.7500e+02 -2.7500e+02  4e-04  7e-15  1e-16
#  6: -2.7500e+02 -2.7500e+02  4e-06  4e-16  7e-17
# Optimal solution found.
# 1.0

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Paired)
plt.show()
